# %%
import pandas as pd

# %% [markdown]
# # 1

# %%
curen={'1 AED':'22.82 INR','1 SAR':'22.34 INR','1 BDT':'0.70 INR','1 CNY':'11.74 INR','1 HKD':'10.76 INR','1 IDR':'0.005 INR','1 KHR':'0.020 INR','1 KRW':'0.062 INR','1 LAK':'0.003 INR','1 LKR':'0.28 INR'}

# %%
curen
# Out:
# {'1 AED': '22.82 INR',
#  '1 SAR': '22.34 INR',
#  '1 BDT': '0.70 INR',
#  '1 CNY': '11.74 INR',
#  '1 HKD': '10.76 INR',
#  '1 IDR': '0.005 INR',
#  '1 KHR': '0.020 INR',
#  '1 KRW': '0.062 INR',
#  '1 LAK': '0.003 INR',
#  '1 LKR': '0.28 INR'}

# %% [markdown]
# ## 2

# %%
football={'Neymar':['10','Al-Hilal'],'Messi':['10','Inter Miami'],'Ronaldo':['7','Al-Nassr']}

# %%
football
# Out:
# {'Neymar': ['10', 'Al-Hilal'],
#  'Messi': ['10', 'Inter Miami'],
#  'Ronaldo': ['7', 'Al-Nassr']}

# %%
f=pd.DataFrame(football,index=['Jersey number','Club'])

# %%
f
# Out:
#                  Neymar        Messi   Ronaldo
# Jersey number        10           10         7
# Club           Al-Hilal  Inter Miami  Al-Nassr

# %% [markdown]
# ## 3

# %%
c={'India':'$3.937 trillion','United States':"$28.78 trillion","China":"$18.53 trillion","Germany":"$4.59 trillion","Japan":"$4.11 trillion","United Kingdom":"$3.5 trillion","France":"$3.13 trillion","Brazil":"$2.33trillion","Italy":"$2.32trillion","Canada":"$2.24trillion"}

# %%
c
# Out:
# {'India': '$3.937 trillion',
#  'United States': '$28.78 trillion',
#  'China': '$18.53 trillion',
#  'Germany': '$4.59 trillion',
#  'Japan': '$4.11 trillion',
#  'United Kingdom': '$3.5 trillion',
#  'France': '$3.13 trillion',
#  'Brazil': '$2.33trillion',
#  'Italy': '$2.32trillion',
#  'Canada': '$2.24trillion'}

# %%
gdp=pd.DataFrame(c,index=['GDP'])

# %%
gdp
# Out:
#                India    United States            China         Germany  \
# GDP  $3.937 trillion  $28.78 trillion  $18.53 trillion  $4.59 trillion
#
#               Japan United Kingdom          France         Brazil  \
# GDP  $4.11 trillion  $3.5 trillion  $3.13 trillion  $2.33trillion
#
#              Italy         Canada
# GDP  $2.32trillion  $2.24trillion

# %%
gdp.iloc[0,1]
# Out:
# '$28.78 trillion'

# %%
High
# Out:
# '$28.78 trillion'

# %%
gdp.iloc[[1,1]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1714, in _iLocIndexer._get_list_axis(self, key, axis)
#    1713 try:
# -> 1714     return self.obj._take_with_is_copy(key, axis=axis)
#    1715 except IndexError as err:
#    1716     # re-raise with different error message, e.g. test_getitem_ndarray_3d
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:4153, in NDFrame._take_with_is_copy(self, indices, axis)
#    4144 """
#    4145 Internal version of the `take` method that sets the `_is_copy`
#    4146 attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4151 See the docstring of `take` for full explanation of the parameters.
#    4152 """
# -> 4153 result = self.take(indices=indices, axis=axis)
# ...

# %%
Low
# Out:
#                India    United States            China         Germany  \
# GDP  $3.937 trillion  $28.78 trillion  $18.53 trillion  $4.59 trillion
#
#               Japan United Kingdom          France         Brazil  \
# GDP  $4.11 trillion  $3.5 trillion  $3.13 trillion  $2.33trillion
#
#              Italy         Canada
# GDP  $2.32trillion  $2.24trillion

# %% [markdown]
# ## 20/08/24

# %%
pd.read_csv("pandas_docs/stack-overflow-developer-survey-2019/survey_results_public.csv")
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
survey=pd.read_csv("pandas_docs/stack-overflow-developer-survey-2019/survey_results_public.csv")

# %%
survey
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
survey.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
survey.loc[9999,'Sexuality']
# Out:
# 'Straight / Heterosexual'

# %%
survey.loc[29,'Age']
# Out:
# 28.0

# %%
survey.loc[299,'DevType']
# Out:
# 'Developer, back-end;Developer, front-end;Developer, full-stack'

# %%
survey.loc[[10,20,30,40,50],'EdLevel']
# Out:
# 10                            Primary/elementary school
# 20                                                  NaN
# 30                            Primary/elementary school
# 40             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 50    Some college/university study without earning ...
# Name: EdLevel, dtype: object

# %%
survey.loc[:100,'Gender']
# Out:
# 0                                                    Man
# 1                                                    Man
# 2                                                    Man
# 3                                                    Man
# 4                                                    Man
#                              ...
# 96     Non-binary, genderqueer, or gender non-conforming
# 97                                                   Man
# 98                                                   Man
# 99                                                 Woman
# 100                                                  NaN
# Name: Gender, Length: 101, dtype: object

# %%
survey
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
index=setattr['Respondent']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 index=setattr['Respondent']
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
